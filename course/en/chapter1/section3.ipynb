# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhijitManepatil/Transformer-HF/blob/main/course/en/chapter1/section3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformers, what can they do?

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 72.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 66.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
classifier(
    ["I am a software developer", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9964225888252258},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "Python Developer with B.E",
    candidate_labels=["education", "skill", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'sequence': 'Python Developer with B.E',
#  'labels': ['skill', 'education', 'business'],
#  'scores': [0.89463210105896, 0.05440458282828331, 0.050963301211595535]}

# %%
from transformers import pipeline
# Text-generation is randomness with the same input
generator = pipeline("text-generation")
generator("I am going for vacation with")
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "I am going for vacation with all of my friends and traveling with them right now. However I'm also going to get a little used to the new life with my family which will be easier and easier. I have the best life in the world."}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# [{'generated_text': 'In this course, we will teach you how to manipulate the world and '
#                     'move your mental and physical capabilities to your advantage.'},
#  {'generated_text': 'In this course, we will teach you how to become an expert and '
#                     'practice realtime, and with a hands on experience on both real '
#                     'time and real'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'score': 0.19619810581207275,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.04052736610174179,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %%
unmasker = pipeline("fill-mask")
unmasker("I am <mask> engineer working in IT company as a software developer", top_k=5)
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'score': 0.8711416721343994,
#   'token': 41,
#   'token_str': ' an',
#   'sequence': 'I am an engineer working in IT company as a software developer'},
#  {'score': 0.08345260471105576,
#   'token': 2257,
#   'token_str': ' software',
#   'sequence': 'I am software engineer working in IT company as a software developer'},
#  {'score': 0.006312999874353409,
#   'token': 11143,
#   'token_str': ' Software',
#   'sequence': 'I am Software engineer working in IT company as a software developer'},
#  {'score': 0.00426116120070219,
#   'token': 3779,
#   'token_str': ' IT',
#   'sequence': 'I am IT engineer working in IT company as a software developer'},
#  {'score': 0.0017278296872973442,
#   'token': 949,
#   'token_str': ' senior',
# ...

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/token_classification.py:159: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# [{'entity_group': 'PER',
#   'score': 0.9981694,
#   'word': 'Sylvain',
#   'start': 11,
#   'end': 18},
#  {'entity_group': 'ORG',
#   'score': 0.9796019,
#   'word': 'Hugging Face',
#   'start': 33,
#   'end': 45},
#  {'entity_group': 'LOC',
#   'score': 0.9932106,
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %%
ner("I am Abhijit Manepatil have completed B.Tech from University of Pune working in a trigyn Technology as a Software Engineer")
# Out:
# [{'entity_group': 'PER',
#   'score': 0.98678744,
#   'word': 'Abhijit Manepatil',
#   'start': 5,
#   'end': 22},
#  {'entity_group': 'ORG',
#   'score': 0.9540973,
#   'word': 'University of Pune',
#   'start': 50,
#   'end': 68}]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.3860921561717987,
#  'start': 82,
#  'end': 99,
#  'answer': 'trigyn Technology'}

# %%
question_answerer(
    question="what is the name of employee",
    context="I am Abhijit Manepatil have completed B.Tech from University of Pune working in a trigyn Technology as a Software Engineer"
)
# Out:
# {'score': 0.9016438722610474,
#  'start': 5,
#  'end': 22,
#  'answer': 'Abhijit Manepatil'}

# %%
question_answerer(
    question="who is software engineer",
    context="I am Abhijit Manepatil have completed B.Tech from University of Pune working in a trigyn Technology as a Software Engineer"
)
# Out:
# {'score': 0.7937835454940796,
#  'start': 5,
#  'end': 22,
#  'answer': 'Abhijit Manepatil'}

# %%
question_answerer(
    question="who is working in trigyn technology as software engineer",
    context="I am Abhijit Manepatil have completed B.Tech from University of Pune working in a trigyn Technology as a Software Engineer"
)
# Out:
# {'score': 0.6737417578697205,
#  'start': 5,
#  'end': 22,
#  'answer': 'Abhijit Manepatil'}

# %%
question_answerer(
    question="Who has a B.Tech degree",
    context="I am Abhijit Manepatil have completed B.Tech from University of Pune working in a trigyn Technology as a Software Engineer"
)
# Out:
# {'score': 0.737140417098999,
#  'start': 5,
#  'end': 22,
#  'answer': 'Abhijit Manepatil'}

# %%
question_answerer(
    question="Who has a completed b.tech from Pune University",
    context="I am Abhijit Manepatil have completed B.Tech from University of Pune working in a trigyn Technology as a Software Engineer"
)
# Out:
# {'score': 0.5362269878387451,
#  'start': 5,
#  'end': 22,
#  'answer': 'Abhijit Manepatil'}

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)
# Out:
# [{'summary_text': ' America has changed dramatically during recent years . The '
#                   'number of engineering graduates in the U.S. has declined in '
#                   'traditional engineering disciplines such as mechanical, civil '
#                   ', electrical, chemical, and aeronautical engineering . Rapidly '
#                   'developing economies such as China and India, as well as other '
#                   'industrial countries in Europe and Asia, continue to encourage '
#                   'and advance engineering .'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# [{'translation_text': 'This course is produced by Hugging Face.'}]
